# %%
import pandas as pd
import random
import datetime
import numpy as np

# %%
data = pd.read_csv('/Users/idanvazana/Desktop/למידת מכונה/פרויקט/games.csv')

# %%
random.seed(1)
data['risk_rate'] = [round(random.random(), 2) for k in data.index]
data['experience'] = [round(random.randint(1,20)) for k in data.index]
data
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.500000e+12  1.500000e+12     13      outoftime
# 1      l1NXvwaE   True  1.500000e+12  1.500000e+12     16         resign
# 2      mIICvQHh   True  1.500000e+12  1.500000e+12     61           mate
# 3      kWKvrqYL   True  1.500000e+12  1.500000e+12     61           mate
# 4      9tXo1AUZ   True  1.500000e+12  1.500000e+12     95           mate
# ...         ...    ...           ...           ...    ...            ...
# 16378  bUzxETNU   True  1.500000e+12  1.500000e+12     42         resign
# 16379  v9F8TSC8   True  1.500000e+12  1.500000e+12    100         resign
# 16380  sKkq0dBb   True  1.500000e+12  1.500000e+12     63           mate
# 16381  tsuvLqR4   True  1.500000e+12  1.500000e+12     64         resign
# 16382  4eGGUWBo  False  1.480000e+12  1.480000e+12     66      outoftime
#
#       winner increment_code       white_id  white_rating      black_id  \
# ...

# %%
## Try to fix the timestamp
'''
def convert_timestamp(timestamp):
    timestamp = float(timestamp)
    dt = datetime.datetime.fromtimestamp(timestamp)
    formatted_timestamp = dt.strftime("%Y-%m-%d %H:%M:%S")

    return formatted_timestamp


#min(data['created_at']).drop()

#data['min_created'] = np.where(data.created_at.min(), 1, 0)
data.astype({'created_at': 'float64'})

data['gap_time'] = data['last_move_at'] - data['created_at']
#data['gap_timestamp'] = datetime.datetime.fromtimestamp(data['gap_time'])


# Apply the conversion function to the 'timestamp' column of the DataFrame
data['last_move_at'] = data['last_move_at'].apply(convert_timestamp)

'''
# Out:
# '\ndef convert_timestamp(timestamp):\n    timestamp = float(timestamp)\n    dt = datetime.datetime.fromtimestamp(timestamp)\n    formatted_timestamp = dt.strftime("%Y-%m-%d %H:%M:%S")\n\n    return formatted_timestamp\n\n\n#min(data[\'created_at\']).drop()\n\n#data[\'min_created\'] = np.where(data.created_at.min(), 1, 0)\ndata.astype({\'created_at\': \'float64\'})\n\ndata[\'gap_time\'] = data[\'last_move_at\'] - data[\'created_at\']\n#data[\'gap_timestamp\'] = datetime.datetime.fromtimestamp(data[\'gap_time\'])\n\n\n# Apply the conversion function to the \'timestamp\' column of the DataFrame\ndata[\'last_move_at\'] = data[\'last_move_at\'].apply(convert_timestamp)\n\n'

# %%
data.dropna(inplace = True)
new = data["moves"].str.split(" ", n = 5, expand = True)
i=1
while i<6:
    try:
        data["Move ", i]= new[i-1]
    except:
        data["Move ", i]= "Null"
    i +=1

data.drop('moves',inplace=True, axis=1)
data
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.500000e+12  1.500000e+12     13      outoftime
# 1      l1NXvwaE   True  1.500000e+12  1.500000e+12     16         resign
# 2      mIICvQHh   True  1.500000e+12  1.500000e+12     61           mate
# 3      kWKvrqYL   True  1.500000e+12  1.500000e+12     61           mate
# 4      9tXo1AUZ   True  1.500000e+12  1.500000e+12     95           mate
# ...         ...    ...           ...           ...    ...            ...
# 16378  bUzxETNU   True  1.500000e+12  1.500000e+12     42         resign
# 16379  v9F8TSC8   True  1.500000e+12  1.500000e+12    100         resign
# 16380  sKkq0dBb   True  1.500000e+12  1.500000e+12     63           mate
# 16381  tsuvLqR4   True  1.500000e+12  1.500000e+12     64         resign
# 16382  4eGGUWBo  False  1.480000e+12  1.480000e+12     66      outoftime
#
#       winner increment_code       white_id  white_rating  ... opening_eco  \
# ...
